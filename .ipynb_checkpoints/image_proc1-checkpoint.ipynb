# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./DATA/rainbow.jpg')

# %%
plt.imshow(img)

# %%
img = cv2.imread('./DATA/rainbow.jpg',0)

# %%
plt.imshow(img)
